# %%
import os
import shutil
import pickle
import numpy as np
from pydub import AudioSegment

import sys

import numpy as np
import os
from sklearn.metrics import classification_report, recall_score, precision_score, f1_score
#import pandas as pd
from __future__ import print_function
import time

import numpy as np
import pandas as pd

import torch

import torch.nn.functional as F
import os
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import seaborn as sns
import matplotlib

import matplotlib.pyplot as plt

from sklearn.utils.class_weight import compute_class_weight

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 3))

N = 6
ind = np.arange(N) 
width = 0.16
  
## rp: nls, german, czech, gita, italian
# neuro: tdu 
    
    
CB_color_cycle = ['#377eb8', '#ff7f00', '#4daf4a',
              '#f781bf', '#a65628', '#984ea3',
              '#999999', '#e41a1c', '#dede00']

#xvec = [65, 75, 74, 83, 76, 85]    
xvec = [63, 82, 70, 77, 76, 83]  
bar1 = plt.bar(ind, xvec, width, color=CB_color_cycle[0])

wav2vec = [63, 91, 78, 83, 76, 83]
bar2 = plt.bar(ind+width, wav2vec, width, color=CB_color_cycle[1])
  
trill =  [66, 90, 79, 77, 84, 89]
bar3 = plt.bar(ind+width*2, trill, width, color=CB_color_cycle[2])
  
hubert = [60, 90, 77, 84, 74, 84]  
bar4= plt.bar(ind+width*3, hubert, width, color=CB_color_cycle[3])
plt.yticks(fontsize=14)     
#plt.xlabel("Data sets", weight='bold',  fontsize=14)
plt.ylabel('F-1 score (%)', weight='bold',  fontsize=14)
#plt.title("Monolingual Experiments", )
  
plt.xticks(ind+1.5*width, ['NLS', 'Neurovoz', 'GermanPD', 'CzechPD', 'GITA', 'ItalianPVS'], rotation=20, fontsize=14)
plt.legend((bar1, bar2, bar3, bar4), ('Xvector', 'Wav2Vec 2.0', 'TRILLsson', 'Hubert'), ncol=4, fontsize=14, bbox_to_anchor=(0.5, 1.1), loc='center') 
plt.savefig('/Users/annafavaro/Downloads/mono_tdu.jpg', dpi=600, bbox_inches="tight")

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 3))

N = 6
ind = np.arange(N) 
width = 0.16
  
  
CB_color_cycle = ['#377eb8', '#ff7f00', '#4daf4a',
              '#f781bf', '#a65628', '#984ea3',
              '#999999', '#e41a1c', '#dede00']

#xvec = [78, 70, 76, 71, 76, 80] #tdu x italian  
xvec = [64, 84, 70, 68, 72, 90]
bar1 = plt.bar(ind, xvec, width, color=CB_color_cycle[0])

wav2vec = [76, 91, 77, 82, 82, 90]
bar2 = plt.bar(ind+width, wav2vec, width, color=CB_color_cycle[1])
  
trill = [67, 84, 85, 91, 80, 90]
bar3 = plt.bar(ind+width*2, trill, width, color=CB_color_cycle[2])
  
hubert = [62, 84, 79, 87, 73, 92]  
bar4= plt.bar(ind+width*3, hubert, width, color=CB_color_cycle[3])
plt.yticks(fontsize=14)    
#plt.xlabel("Data sets", weight='bold',  fontsize=14)
plt.ylabel('F-1 score (%)', weight='bold',  fontsize=14)
#plt.title("Monolingual Experiments", )
  
plt.xticks(ind+1.5*width, ['NLS', 'Neurovoz', 'GermanPD', 'CzechPD', 'GITA', 'ItalianPVS'], rotation=20, fontsize=14)
plt.legend((bar1, bar2, bar3, bar4), ('Xvector', 'Wav2Vec 2.0', 'TRILLsson', 'Hubert'), ncol=4, fontsize=14, bbox_to_anchor=(0.5, 1.1), loc='center')
#plt.legend((bar1, bar2, bar3, bar4), ('xvector', 'wav2vec2.0', 'TRILLsson', 'Hubert'), fontsize=10, bbox_to_anchor=(1.0, 2.0), loc='best') 
plt.savefig('/Users/annafavaro/Downloads/multi_tdu.jpg', dpi=600, bbox_inches="tight")

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 3))

N = 6
ind = np.arange(N) 
width = 0.16
  
  
CB_color_cycle = ['#377eb8', '#ff7f00', '#4daf4a',
              '#f781bf', '#a65628', '#984ea3',
              '#999999', '#e41a1c', '#dede00']

xvec = [54, 60, 60, 62, 61, 79]  
bar1 = plt.bar(ind, xvec, width, color=CB_color_cycle[0])

wav2vec = [61, 72, 62, 77, 69, 74]
bar2 = plt.bar(ind+width, wav2vec, width, color=CB_color_cycle[1])
  
trill = [30, 69, 57, 74, 55, 69]
bar3 = plt.bar(ind+width*2, trill, width, color=CB_color_cycle[2])
  
hubert = [64, 77, 67, 82, 71, 68]  
bar4= plt.bar(ind+width*3, hubert, width, color=CB_color_cycle[3])
plt.yticks(fontsize=14)    
#plt.xlabel("Data sets", weight='bold',  fontsize=14)
plt.ylabel('F-1 score (%)', weight='bold',  fontsize=16)
#plt.title("Monolingual Experiments", )
  
plt.xticks(ind+1.5*width, ['NLS', 'Neurovoz', 'GermanPD', 'CzechPD', 'GITA', 'ItalianPVS'], rotation=20, fontsize=14)
plt.legend((bar1, bar2, bar3, bar4), ('Xvector', 'Wav2Vec 2.0', 'TRILLsson', 'Hubert'), ncol=4, fontsize=14, bbox_to_anchor=(0.5, 1.1), loc='center')
plt.savefig('/Users/annafavaro/Downloads/cross_tdu.jpg', dpi=600,   bbox_inches="tight")

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 3))

N = 6
ind = np.arange(N) 
width = 0.14
  
  
CB_color_cycle = ['#377eb8', '#ff7f00', '#4daf4a',
              '#f781bf', '#a65628', '#984ea3',
              '#999999', '#e41a1c', '#dede00']

svm = [73, 82, 70, 71, 50, 90]    
bar1 = plt.bar(ind, svm, width, color=CB_color_cycle[-1])

knn = [61, 74, 73, 73, 54, 87]
bar2 = plt.bar(ind+width, knn, width, color=CB_color_cycle[-2])
  
rf = [70, 73, 70, 78, 51, 88]
bar3 = plt.bar(ind+width*2, rf, width, color=CB_color_cycle[-4])
  
xg = [73, 80, 70, 79, 55, 98]  
bar4= plt.bar(ind+width*3, xg, width, color=CB_color_cycle[-6])

bagging = [69, 74, 73, 80, 56, 92]  
bar5= plt.bar(ind+width*4, bagging, width, color=CB_color_cycle[-7])
  
#plt.xlabel("Data sets", weight='bold',  fontsize=14)
plt.ylabel('F-1 score (%)', weight='bold',  fontsize=14)
#plt.title("Monolingual Experiments", )
  
plt.yticks(fontsize=14)    

plt.xticks(ind+2*width, ['NLS', 'Neurovoz', 'GermanPD', 'CzechPD', 'GITA', 'ItalianPVS'], rotation=20, fontsize=14)
plt.legend((bar1, bar2, bar3, bar4, bar5), ('SVM', 'KNN', 'RF', 'XGBoost', 'BG'), ncol=5, fontsize=14, bbox_to_anchor=(0.5, 1.1), loc='center')
#plt.legend((bar1, bar2, bar3, bar4), ('xvector', 'wav2vec2.0', 'TRILLsson', 'Hubert'), fontsize=10, bbox_to_anchor=(1.0, 2.0), loc='best') 
plt.savefig('/Users/annafavaro/Downloads/mono_inter.jpg', dpi=600, bbox_inches="tight")

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 3))

N = 3
ind = np.arange(N) 
width = 0.12
  
  
CB_color_cycle = ['#377eb8', '#ff7f00', '#4daf4a',
              '#f781bf', '#a65628', '#984ea3',
              '#999999', '#e41a1c', '#dede00']

ctrl = [57, 59, 61]    
bar1 = plt.bar(ind, ctrl, width, color=CB_color_cycle[1])

ad = [59, 59, 59]
bar2 = plt.bar(ind+width, ad, width, color=CB_color_cycle[2])
  
pdm = [50, 49, 54]
bar3 = plt.bar(ind+width*2, pdm, width, color=CB_color_cycle[0])
  
pd = [56, 58, 61]  
bar4= plt.bar(ind+width*3, pd, width, color=CB_color_cycle[8])


#plt.xlabel("Data sets", weight='bold',  fontsize=14)
plt.ylabel('F-1 score (%)', weight='bold',  fontsize=14)
#plt.title("Monolingual Experiments", )
  
plt.yticks(fontsize=14)    

plt.xticks(ind+1.5*width, ['Rainbow Passage', 'Joke', 'Poem'], fontsize=14 )
plt.legend((bar1, bar2, bar3, bar4), ("Controls", "Alzheimer's", "Parkinson's mimics", "Parkinson's"), ncol=4, fontsize=14, bbox_to_anchor=(0.5, 1.1), loc='center')
#plt.legend((bar1, bar2, bar3, bar4), ('xvector', 'wav2vec2.0', 'TRILLsson', 'Hubert'), fontsize=10, bbox_to_anchor=(1.0, 2.0), loc='best') 
plt.savefig('/Users/annafavaro/Downloads/Helin_ASR.jpg', dpi=600, bbox_inches="tight")

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 3))

N = 3
ind = np.arange(N) 
width = 0.12
  
  
CB_color_cycle = ['#377eb8', '#ff7f00', '#4daf4a',
              '#f781bf', '#a65628', '#984ea3',
              '#999999', '#e41a1c', '#dede00']



ctrl = [57, 59, 61]    
bar1 = plt.bar(ind, ctrl, width, color=CB_color_cycle[1])

ad = [59, 59, 59]
bar2 = plt.bar(ind+width, ad, width, color=CB_color_cycle[2])
  
pdm = [50, 49, 54]
bar3 = plt.bar(ind+width*2, pdm, width, color=CB_color_cycle[0])
  
pd = [56, 58, 61]  
bar4= plt.bar(ind+width*3, pd, width, color=CB_color_cycle[8])


#plt.xlabel("Data sets", weight='bold',  fontsize=14)
plt.ylabel('F-1 score (%)', weight='bold',  fontsize=14)
#plt.title("Monolingual Experiments", )
  
plt.yticks(fontsize=14)    

plt.xticks(ind+1.5*width, ['Rainbow Passage', 'Joke', 'Poem'], fontsize=14 )
plt.legend((bar1, bar2, bar3, bar4), ("Controls", "Alzheimer's", "Parkinson's mimics", "Parkinson's"), ncol=4, fontsize=14, bbox_to_anchor=(0.5, 1.1), loc='center')
#plt.legend((bar1, bar2, bar3, bar4), ('xvector', 'wav2vec2.0', 'TRILLsson', 'Hubert'), fontsize=10, bbox_to_anchor=(1.0, 2.0), loc='best') 
#plt.savefig('/Users/annafavaro/Downloads/.jpg', dpi=600, bbox_inches="tight")

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 3))

N = 3
ind = np.arange(N) 
width = 0.12
  
  
CB_color_cycle = ['#377eb8', '#ff7f00', '#4daf4a',
              '#f781bf', '#a65628', '#984ea3',
              '#999999', '#e41a1c', '#dede00']



ctrl = [89, 90, 90]    
bar1 = plt.bar(ind, ctrl, width, color=CB_color_cycle[1])

ad = [89, 88, 89]
bar2 = plt.bar(ind+width, ad, width, color=CB_color_cycle[2])
  
pdm = [89, 88, 90]
bar3 = plt.bar(ind+width*2, pdm, width, color=CB_color_cycle[0])
  
pd = [88, 89, 90]  
bar4= plt.bar(ind+width*3, pd, width, color=CB_color_cycle[8])


#plt.xlabel("Data sets", weight='bold',  fontsize=14)
plt.ylabel('F-1 score (%)', weight='bold',  fontsize=14)
#plt.title("Voicing")
  
plt.yticks(fontsize=14)    

plt.xticks(ind+1.5*width, ['Rainbow Passage', 'Joke', 'Poem'], fontsize=14 )
plt.legend((bar1, bar2, bar3, bar4), ("Controls", "Alzheimer's", "Parkinson's mimics", "Parkinson's"), ncol=4, fontsize=14, bbox_to_anchor=(0.5, 1.1), loc='center')
#plt.legend((bar1, bar2, bar3, bar4), ('xvector', 'wav2vec2.0', 'TRILLsson', 'Hubert'), fontsize=10, bbox_to_anchor=(1.0, 2.0), loc='best') 
plt.savefig('/Users/annafavaro/Downloads/voicing.jpg', dpi=600, bbox_inches="tight")

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 3))

N = 3
ind = np.arange(N) 
width = 0.12
  
  
CB_color_cycle = ['#377eb8', '#ff7f00', '#4daf4a',
              '#f781bf', '#a65628', '#984ea3',
              '#999999', '#e41a1c', '#dede00']



ctrl = [58, 62, 63]    
bar1 = plt.bar(ind, ctrl, width, color=CB_color_cycle[1])

ad = [62, 64, 63]
bar2 = plt.bar(ind+width, ad, width, color=CB_color_cycle[2])
  
pdm = [56, 55, 60]
bar3 = plt.bar(ind+width*2, pdm, width, color=CB_color_cycle[0])
  
pd = [56, 62, 63]  
bar4= plt.bar(ind+width*3, pd, width, color=CB_color_cycle[8])


#plt.xlabel("Data sets", weight='bold',  fontsize=14)
plt.ylabel('F-1 score (%)', weight='bold',  fontsize=14)
#plt.title("Voicing")
  
plt.yticks(fontsize=14)    

plt.xticks(ind+1.5*width, ['Rainbow Passage', 'Joke', 'Poem'], fontsize=14 )
plt.legend((bar1, bar2, bar3, bar4), ("Controls", "Alzheimer's", "Parkinson's mimics", "Parkinson's"), ncol=4, fontsize=14, bbox_to_anchor=(0.5, 1.1), loc='center')
#plt.legend((bar1, bar2, bar3, bar4), ('xvector', 'wav2vec2.0', 'TRILLsson', 'Hubert'), fontsize=10, bbox_to_anchor=(1.0, 2.0), loc='best') 
plt.savefig('/Users/annafavaro/Downloads/mode.jpg', dpi=600, bbox_inches="tight")

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 3))

N = 3
ind = np.arange(N) 
width = 0.12
  
  
CB_color_cycle = ['#377eb8', '#ff7f00', '#4daf4a',
              '#f781bf', '#a65628', '#984ea3',
              '#999999', '#e41a1c', '#dede00']



ctrl = [65, 66, 70]    
bar1 = plt.bar(ind, ctrl, width, color=CB_color_cycle[1])

ad = [68, 67, 70]
bar2 = plt.bar(ind+width, ad, width, color=CB_color_cycle[2])
  
pdm = [61, 58, 66]
bar3 = plt.bar(ind+width*2, pdm, width, color=CB_color_cycle[0])
  
pd = [63, 66, 68]  
bar4= plt.bar(ind+width*3, pd, width, color=CB_color_cycle[8])


#plt.xlabel("Data sets", weight='bold',  fontsize=14)
plt.ylabel('F-1 score (%)', weight='bold',  fontsize=14)
#plt.title("Voicing")
  
plt.yticks(fontsize=14)    

plt.xticks(ind+1.5*width, ['Rainbow Passage', 'Joke', 'Poem'], fontsize=14 )
plt.legend((bar1, bar2, bar3, bar4), ("Controls", "Alzheimer's", "Parkinson's mimics", "Parkinson's"), ncol=4, fontsize=14, bbox_to_anchor=(0.5, 1.1), loc='center')
#plt.legend((bar1, bar2, bar3, bar4), ('xvector', 'wav2vec2.0', 'TRILLsson', 'Hubert'), fontsize=10, bbox_to_anchor=(1.0, 2.0), loc='best') 
plt.savefig('/Users/annafavaro/Downloads/manner.jpg', dpi=600, bbox_inches="tight")

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# set width of bar
barWidth = 0.1
fig = plt.subplots(figsize =(5, 4))
 
# set height of bar
IT = [89]
ECE = [66]
CSE = [71]
 
# Set position of bar on X axis
br1 = np.arange(len(IT))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
 
# Make the plot
plt.bar(br1, IT, color =CB_color_cycle[1], width = 0.05,
        edgecolor ='grey', label ='Voicing')
plt.bar(br2, ECE, color ='g', width = 0.05,
        edgecolor ='grey', label ='Place')
plt.bar(br3, CSE, color ='b', width = 0.05,
        edgecolor ='grey', label ='Manner')
 
# Adding Xticks
plt.xlabel('Category', fontweight ='bold', fontsize = 15)

plt.ylabel('F-1 score (%)', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(IT))],
        [''])

plt.legend(ncol=3, fontsize=14, bbox_to_anchor=(0.5, 1.1), loc='center')


#plt.legend((bar1, bar2, bar3, bar4), ('xvector', 'wav2vec2.0', 'TRILLsson', 'Hubert'), fontsize=10, bbox_to_anchor=(1.0, 2.0), loc='best') 
plt.savefig('/Users/annafavaro/Downloads/librispeech.jpg', dpi=600, bbox_inches="tight")
